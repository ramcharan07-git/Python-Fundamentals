# %% [markdown]
# PYTHON BASICS:
#
# IT IS DEVELOPED IN 1989.
# IT HAS RELEASED IN 1991.
# it executes line by line by compiler
#
# BASE LANGUAGE USED TO CREATE PYTHON IS C LANGUAGE

# %%
#arthematic operations

a = 4
b = 2
c = a+b #add
d = a-b  #sub
e = a*b  #mul
f = a/b #div in float everytime
g = a//b #floor fiv
h = a%b #modulus operator
k = a**b #exponent
l = a**0.5  #square root
print(a,b,c,d,e,f,g,h,k,l)
# Out:
# 4 2 6 2 8 2.0 2 0 16 2.0
